# %% [markdown]
# ## Manuacturer Policy

# %% [markdown]
# # Manufacturer Policy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("code manufacturer-policy-spreadsheet.csv")

# %%
df[["1", "2", "3", "4"]].plot()
# Out:
# <AxesSubplot:>

# %%
df[["1.1", "2.1", "3.1", "4.1"]].plot()
# Out:
# <AxesSubplot:>

# %%
df[["1.2", "2.2", "3.2", "4.2"]].plot()
# Out:
# <AxesSubplot:>

# %%
df[["1.3", "2.3", "3.3", "4.3"]].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
import scipy.stats as st

# %% [markdown]
# ### Bussiness As Usual

# %%
data = df["1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (9.162, 26.001)

# %%
data = df["1.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (5.035, 17.424)

# %%
data = df["1.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (19.919, 53.205)

# %%
data = df["1.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (16.128, 34.283)

# %% [markdown]
# ### $0.6M for 5 years

# %%
data = df["2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (8.474, 23.355)

# %%
data = df["2.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (6.592, 21.978)

# %%
data = df["2.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (19.335, 48.875)

# %%
data = df["2.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (16.048, 43.626)

# %% [markdown]
# ### $106M for 5 years

# %%
data = df["3"]
print("Mean:", np.mean(data))
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# Mean: 16.040457700609757
# (8.326, 23.754)

# %%
data = df["3.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (5.852, 23.893)

# %%
data = df["3.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (19.14, 50.086)

# %%
data = df["3.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (17.599, 39.216)

# %% [markdown]
# ### $171.1M for 10 years

# %%
data = df["4"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (8.913, 25.927)

# %%
data = df["4.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (7.797, 23.94)

# %%
data = df["4.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (20.084, 54.649)

# %%
data = df["4.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (16.665, 34.376)
