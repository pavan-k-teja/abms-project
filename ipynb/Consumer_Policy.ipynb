# %% [markdown]
# ## Consumer Policy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("code consumer-policy-spreadsheet.csv")

# %%
df[["1", "2", "3", "4"]].plot()
# Out:
# <AxesSubplot:>

# %%
df[["1.1", "2.1", "3.1", "4.1"]].plot()
# Out:
# <AxesSubplot:>

# %%
df[["1.2", "2.2", "3.2", "4.2"]].plot()
# Out:
# <AxesSubplot:>

# %%
df[["1.3", "2.3", "3.3", "4.3"]].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---

# %%
import scipy.stats as st

# %% [markdown]
# ### Bussiness As Usual

# %%
data = df["1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (9.081, 26.676)

# %%
data = df["1.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (6.022, 21.376)

# %%
data = df["1.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (20.05, 51.381)

# %%
data = df["1.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (18.38, 39.958)

# %% [markdown]
# ### $7500 for 5 years

# %%
data = df["2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (8.357, 23.664)

# %%
data = df["2.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (6.257, 27.137)

# %%
data = df["2.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (18.891, 48.867)

# %%
data = df["2.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (16.799, 38.511)

# %% [markdown]
# ### $7500 for 10 years

# %%
data = df["3"]
print("Mean:", np.mean(data))
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# Mean: 18.65912782070732
# (9.538, 27.781)

# %%
data = df["3.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (6.386, 25.649)

# %%
data = df["3.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (20.823, 55.597)

# %%
data = df["3.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (19.09, 42.225)

# %% [markdown]
# ### $15000 for 5 years

# %%
data = df["4"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (9.319, 25.38)

# %%
data = df["4.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (6.578, 23.945)

# %%
data = df["4.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (20.981, 57.979)

# %%
data = df["4.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (17.756, 40.685)
