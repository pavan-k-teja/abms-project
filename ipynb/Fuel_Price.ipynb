# %% [markdown]
# ## Fuel Price

# %% [markdown]
# # Fuel Price

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("code fuel-price-spreadsheet.csv")

# %%
df[["1", "2", "3", "4"]].plot()
# Out:
# <AxesSubplot:>

# %%
df[["1.1", "2.1", "3.1", "4.1"]].plot()
# Out:
# <AxesSubplot:>

# %%
df[["1.2", "2.2", "3.2", "4.2"]].plot()
# Out:
# <AxesSubplot:>

# %%
df[["1.3", "2.3", "3.3", "4.3"]].plot()
# Out:
# <AxesSubplot:>

# %%
import scipy.stats as st

# %% [markdown]
# ### No Change

# %%
data = df["1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (8.645, 24.34)

# %%
data = df["1.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (6.114, 24.549)

# %%
data = df["1.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (19.664, 51.556)

# %%
data = df["1.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (17.659, 42.531)

# %% [markdown]
# ### decrease 20%

# %%
data = df["2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (8.581, 24.06)

# %%
data = df["2.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (5.603, 17.715)

# %%
data = df["2.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (19.503, 49.834)

# %%
data = df["2.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (15.958, 39.748)

# %% [markdown]
# ### increase 20%

# %%
data = df["3"]
print("Mean:", np.mean(data))
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# Mean: 20.723538957000002
# (12.645, 28.802)

# %%
data = df["3.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (2.423, 14.702)

# %%
data = df["3.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (28.046, 57.164)

# %%
data = df["3.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (11.821, 34.629)

# %% [markdown]
# ### increase 40%

# %%
data = df["4"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (12.887, 28.221)

# %%
data = df["4.1"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (1.592, 18.689)

# %%
data = df["4.2"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (26.887, 55.166)

# %%
data = df["4.3"]
tuple(np.round(st.t.interval(alpha=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data)), 3))
# Out:
# (11.983, 32.866)

# %% [markdown]
# ---
